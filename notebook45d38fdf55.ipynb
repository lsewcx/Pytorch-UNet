# %%
# !git clone https://github.com/lsewcx/Pytorch-UNet.git
# Out:
# Cloning into 'Pytorch-UNet'...
# remote: Enumerating objects: 12744, done.
# remote: Counting objects: 100% (2891/2891), done.
# remote: Compressing objects: 100% (194/194), done.
# remote: Total 12744 (delta 2743), reused 2844 (delta 2697), pack-reused 9853 (from 1)
# Receiving objects: 100% (12744/12744), 186.92 MiB | 28.54 MiB/s, done.
# Resolving deltas: 100% (7750/7750), done.

# %%
# %cd Pytorch-UNet
# !git pull
# Out:
# [Errno 2] No such file or directory: 'Pytorch-UNet'
# /kaggle/working/Pytorch-UNet
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 329 bytes | 329.00 KiB/s, done.
# From https://github.com/lsewcx/Pytorch-UNet
#    e86c533..5479ff7  master     -> origin/master
# Updating e86c533..5479ff7
# Fast-forward
#  unet/unet_model.py | 4 ++--
#  1 file changed, 2 insertions(+), 2 deletions(-)

# %%
# %cd Pytorch-UNet
# !rm -rf NEU_Seg-main
# !unzip -q ceping/NEU_Seg-main.zip
# Out:
# /kaggle/working/Pytorch-UNet

# %%
# !rm -rf best_model.pth best_model.pt
# !python train.py --classes 4 --batch-size 16 --epochs 50 --scale 0.5 --model UNetInception --v 10
# Out:
# INFO: Using device cuda
# INFO: Network: UNetInception
# INFO: Network:
# 	3 input channels
# 	4 output channels (classes)
#
# INFO: Creating dataset with 3630 examples
# INFO: Scanning mask files to determine unique values
#   0%|                                                  | 0/3630 [00:00<?, ?it/s]
# INFO: Creating dataset with 3630 examples
# INFO: Scanning mask files to determine unique values
# 100%|██████████████████████████████████████| 3630/3630 [00:08<00:00, 414.43it/s]
# INFO: Unique mask values: [0, 1, 2, 3]
# wandb: Currently logged in as: anony-moose-258745133783792607. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.18.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.17.7
# wandb: Run data is saved locally in /kaggle/working/Pytorch-UNet/wandb/run-20240912_023631-s2vzxln6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run copper-sponge-2
# ...

# %%
# !rm -rf archive_name.zip /kaggle/working/Pytorch-UNet/test_predictions 
# %cd /kaggle/working/Pytorch-UNet
# !python predict.py --model best_model.pth --scale 0.5 --model-name UNetInception
# !zip -r -q archive_name.zip /kaggle/working/Pytorch-UNet/test_predictions /kaggle/working/Pytorch-UNet/best_model.pt /kaggle/working/Pytorch-UNet/best_model.pth
# Out:
# /kaggle/working/Pytorch-UNet
# /kaggle/working/Pytorch-UNet/predict.py:83: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   net=torch.load(args.model)

# %%
# !mv best_model.pth ceping/
# !mv test_predictions ceping/

# %%
# %cd ceping/
# !python main.py
# %cd ..
# Out:
# /kaggle/working/Pytorch-UNet/ceping
# /kaggle/working/Pytorch-UNet/ceping/main.py:27: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !pip install torchview
# !python model_vis_torchview.py
